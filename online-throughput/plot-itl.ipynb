# %%
import json

# Load the benchmark results
file = "./openai-infqps-concurrency32-Qwen3-4B-20260120-144407.json"
with open(file, 'r') as f:
    results = json.load(f)

list(map(len, results['itls']))
results
